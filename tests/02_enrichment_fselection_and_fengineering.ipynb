# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.preprocessing import StandardScaler
pd.options.display.max_columns = None

# %%
df = pd.read_csv('./data/occurrence_cleaned.txt')

# %%
df.head()
# Out:
#              eventDate  month  day            waterBody countryCode  \
# 0  2019-05-29T10:06:00      5   29  South Pacific Ocean          WS
# 1  2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 2  2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 3  2019-05-30T12:04:00      5   30  South Pacific Ocean          WS
# 4  2019-05-30T10:02:00      5   30  South Pacific Ocean          WS
#
#     locality                 species  dive_id  decimalLatitude  \
# 0     Taliga          Chelonia mydas     2422         -13.9387
# 1  Cowabunga  Eretmochelys imbricata     2423         -13.9387
# 2  Cowabunga          Chelonia mydas     2423         -13.9387
# 3  Cowabunga          Chelonia mydas     2425         -13.9387
# 4  Cowabunga  Eretmochelys imbricata     2424         -13.9387
#
#    decimalLongitude  depth  orderKey  familyKey   genusKey  speciesKey
# 0          -171.553  13.50     793.0     9413.0  2441864.0   2442225.0
# 1          -171.553  10.20     793.0     9413.0  2442206.0   8841716.0
# 2          -171.553  10.20     793.0     9413.0  2441864.0   2442225.0
# 3          -171.553   9.75     793.0     9413.0  2441864.0   2442225.0
# 4          -171.553  10.50     793.0     9413.0  2442206.0   8841716.0

# %%
df_common_names.columns
# Out:
# Index(['orderKey', 'familyKey', 'genusKey', 'speciesKey', 'common_name_order',
#        'common_name_family', 'common_name_genus', 'common_name_species',
#        'common_name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36726 entries, 0 to 36725
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   eventDate         36726 non-null  object
#  1   month             36726 non-null  int64
#  2   day               36726 non-null  int64
#  3   waterBody         36726 non-null  object
#  4   countryCode       36726 non-null  object
#  5   locality          36726 non-null  object
#  6   species           36726 non-null  object
#  7   dive_id           36726 non-null  int64
#  8   decimalLatitude   36726 non-null  float64
#  9   decimalLongitude  36726 non-null  float64
#  10  depth             36726 non-null  float64
#  11  orderKey          36715 non-null  float64
#  12  familyKey         36726 non-null  float64
#  13  genusKey          36726 non-null  float64
#  14  speciesKey        36726 non-null  float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 4.2+ MB

# %%
df_common_names = pd.read_csv('./data/common_names.csv')
df_common_names.shape
# Out:
# (3917, 9)

# %%
df_common_names.dropna(subset=['common_name_order','common_name_family','common_name_genus','common_name_species'], how='all', inplace=True)
df_common_names.drop('Unnamed: 0', inplace=True, axis=1)
df_common_names.shape
# Out:
# (3797, 8)

# %%
df_common_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3797 entries, 0 to 3916
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   orderKey             3797 non-null   int64
#  1   familyKey            3797 non-null   int64
#  2   genusKey             3797 non-null   int64
#  3   speciesKey           3797 non-null   int64
#  4   common_name_order    3405 non-null   object
#  5   common_name_family   3154 non-null   object
#  6   common_name_genus    1447 non-null   object
#  7   common_name_species  3238 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 267.0+ KB

# %%
df_common_names['common_name_order'].value_counts()
# Out:
# perch-like fish        1392
# decapod                 250
# mail-cheeked fishes     189
# cowfishes               180
# eel                     161
#                        ...
# chimaera                  1
# swamp eels                1
# crocodilian               1
# brine shrimp              1
# heart urchin              1
# Name: common_name_order, Length: 86, dtype: int64

# %%
df_common_names['common_name_family'].value_counts()
# Out:
# groupers                      146
# rainbowfishes                 128
# damselfishes                  115
# goby                           92
# firefishes                     87
#                              ...
# paddlefish                      1
# eel cods                        1
# flannel-mouth characiforms      1
# sand eels                       1
# land hermit crabs               1
# Name: common_name_family, Length: 374, dtype: int64

# %%
df_common_names['common_name_genus'].value_counts()
# Out:
# common morays         52
# butterflyfishes       51
# groupers              46
# common snappers       44
# parrotfishes          32
#                       ..
# false killer whale     1
# common anchovies       1
# common carps           1
# flathead catfishes     1
# sevengill shark        1
# Name: common_name_genus, Length: 396, dtype: int64

# %%
df_common_names.dropna(subset=['common_name_family'])\
               [df_common_names.dropna(subset=['common_name_family'])['common_name_family'].str.contains('moray')]
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 2          495       2953   2404390     2404391               eel
# 3          495       2953   2403463     2403808               eel
# 91         495       2953   2403463     2403964               eel
# 146        495       2953   2403463     2403789               eel
# 158        495       2953   2403463     2404065               eel
# ...        ...        ...       ...         ...               ...
# 3535       495       2953   2403463     2403798               eel
# 3600       495       2953   2403463     2403870               eel
# 3671       495       2953   2403463     2403993               eel
# 3747       495       2953        -1          -1               eel
# 3816       495       2953   2404269          -1               eel
#
#      common_name_family     common_name_genus common_name_species
# 2            moray eels                   NaN     Brummer's moray
# 3            moray eels         common morays    Blackpearl moray
# 91           moray eels         common morays         green moray
# 146          moray eels         common morays       painted moray
# 158          moray eels         common morays       spotted moray
# ...                 ...                   ...                 ...
# 3535         moray eels         common morays       polygon moray
# 3600         moray eels         common morays        masked moray
# 3671         moray eels         common morays   white-edged moray
# 3747         moray eels                   NaN                 NaN
# 3816         moray eels  giant slender morays                 NaN
#
# [93 rows x 8 columns]

# %%
df_common_names[(df_common_names['common_name_family'].isna()) & 
               (~df_common_names['common_name_genus'].isna())]
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 39         980       7041   2292460     5859647          sea slug
# 256        560       7740   3195825     5422479               NaN
# 268    7431046    2251555   7464943     5183631               NaN
# 301        980       6561   2292101     2292107          sea slug
# 376        714       8153   7673664     5184681       stony coral
# ...        ...        ...       ...         ...               ...
# 3742       714       8219   2260060     5184733       stony coral
# 3753       714       8153   7673664          -1       stony coral
# 3850       705       5688   8424301     2256565       sea anemone
# 3874      1437       8198   2258179          -1       soft corals
# 3906      1437       7313   1002810          -1       soft corals
#
#      common_name_family                common_name_genus   common_name_species
# 39                  NaN  atromaculata leopard nudibranch  Swiss cow nudibranch
# 256                 NaN                             Kelp       oarweed, tangle
# 268                 NaN                   boring sponges         boring sponge
# 301                 NaN                            doris     hairy spiny doris
# 376                 NaN                      horn corals        staghorn coral
# ...                 ...                              ...                   ...
# 3742                NaN                      brain coral   lesser valley coral
# 3753                NaN                      horn corals                   NaN
# 3850                NaN                      Sea anemone    strawberry anemone
# 3874                NaN                         sea fans                   NaN
# 3906                NaN                organ-pipe corals                   NaN
#
# [84 rows x 8 columns]

# %%
df_common_names[(df_common_names['common_name_family'].isna()) & 
               (~df_common_names['common_name_order'].isna())]
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 4          980       7046   2292371     4596863          sea slug
# 11         980    4304701   2292240     2292241          sea slug
# 12         537    4287106   2353403     7193779          leporins
# 17         459       6835   2289226     2289632           octopus
# 33         980       6560   4359787     4359788          sea slug
# ...        ...        ...       ...         ...               ...
# 3901       980       6556   2291830     2291831          sea slug
# 3904       496         -1        -1          -1        silverside
# 3906      1437       7313   1002810          -1       soft corals
# 3910       980       6560        -1          -1          sea slug
# 3912       587         -1        -1          -1   perch-like fish
#
#      common_name_family  common_name_genus   common_name_species
# 4                   NaN                NaN                   NaN
# 11                  NaN                NaN           hermissenda
# 12                  NaN                NaN                   NaN
# 17                  NaN                NaN                   NaN
# 33                  NaN                NaN                   NaN
# ...                 ...                ...                   ...
# 3901                NaN                NaN  sargassum nudibranch
# 3904                NaN                NaN                   NaN
# 3906                NaN  organ-pipe corals                   NaN
# 3910                NaN                NaN                   NaN
# 3912                NaN                NaN                   NaN
#
# [487 rows x 8 columns]

# %%
df_common_names[df_common_names['common_name_order'] == 'octopus']
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 17         459       6835   2289226     2289632           octopus
# 81         459       6833   2289247     2289252           octopus
# 191        459       6835   2289226     2289506           octopus
# 223        459       6835   2289226     2289671           octopus
# 233        459       6835   2289226          -1           octopus
# 286        459       6833   2289247     2289258           octopus
# 372        459       3444   2289296     5189592           octopus
# 442        459       6835   2289226     2289544           octopus
# 472        459       6833   2289247     2289260           octopus
# 524        459       6835   2289226     2289640           octopus
# 576        459       6835   2289226     2289709           octopus
# 585        459       6835   2289226     2289580           octopus
# 872        459    7594089   2289483     2289485           octopus
# 889        459       6839   2289215     2289216           octopus
# 927        459       6835   2289226     2289507           octopus
# 986        459       6835   2289226     2289535           octopus
# 988        459       6835   2289226     2289620           octopus
# 1054       459    7946204   2289346     2289348           octopus
# 1129       459       6835   4621787          -1           octopus
# 1266       459       6835   2289323     2289331           octopus
# 1320       459       6835   4621790     5856033           octopus
# 1353       459       6835   4357170     4357171           octopus
# 1466       459       6835   2289226     2289644           octopus
# 1494       459       6833   2289261     2289280           octopus
# 1536       459       6835   2289226     2289662           octopus
# 1548       459       6835   2289226     2289643           octopus
# 1734       459       6835   2289226     2289628           octopus
# 1769       459       6835   2289226     2289695           octopus
# 1804       459    7594089   4621781     9328249           octopus
# 1857       459       6835   4304632     5856036           octopus
# 2129       459    7594089   4621781     8934572           octopus
# 2280       459       6833   2289247     2289248           octopus
# 2329       459       6835   2289226     2289655           octopus
# 2389       459    7712150   2289465     2289480           octopus
# 2610       459       6835   2289226     2289658           octopus
# 2663       459       3441   2289334     2289810           octopus
# 2739       459       6835   2289501     2289503           octopus
# 2750       459       6835   2289226     2289693           octopus
# 2767       459       6835   2289226     2289589           octopus
# 2768       459       3444   2289227     2289228           octopus
# 2809       459       6835   2289226     2289517           octopus
# 2886       459       6835   2289226     2289636           octopus
# 2957       459       6835   2289729     2289730           octopus
# 3133       459       6833   2289247     2289251           octopus
# 3163       459       6838   2289744     5189601           octopus
# 3222       459    7712150   2289370     2289371           octopus
# 3438       459       6835   2289725     2289726           octopus
# 3589       459       6833   2289247     2289249           octopus
# 3685       459         -1        -1          -1           octopus
# 3729       459       6835   2289438     2289439           octopus
#
#      common_name_family common_name_genus           common_name_species
# 17                  NaN               NaN                           NaN
# 81                  NaN               NaN                           NaN
# 191                 NaN               NaN                           NaN
# 223                 NaN               NaN                common octopus
# 233                 NaN               NaN                           NaN
# 286                 NaN               NaN                           NaN
# 372                 NaN               NaN             Telescope octopus
# 442                 NaN               NaN                           NaN
# 472                 NaN               NaN  Japanese pancake devilfishes
# 524                 NaN               NaN                Sydney octopus
# 576                 NaN               NaN                           NaN
# 585                 NaN               NaN        Caribbean reef octopus
# 872                 NaN               NaN   North Pacific giant octopus
# 889                 NaN               NaN             Seven-arm octopus
# 927                 NaN               NaN                  pale octopus
# 986                 NaN               NaN               Cyane's octopus
# 988                 NaN               NaN        Atlantic pygmy octopus
# 1054                NaN               NaN                curled octopus
# 1129                NaN               NaN                           NaN
# 1266                NaN               NaN           blue-ringed octopus
# 1320                NaN               NaN                           NaN
# 1353                NaN               NaN                 mimic octopus
# 1466                NaN               NaN   California two-spot octopus
# 1494                NaN               NaN                           NaN
# 1536                NaN               NaN                           NaN
# 1548                NaN               NaN               bighead octopus
# 1734                NaN               NaN                  reef octopus
# 1769                NaN               NaN                           NaN
# 1804                NaN               NaN                           NaN
# 1857                NaN               NaN                           NaN
# 2129                NaN               NaN                           NaN
# 2280                NaN               NaN              flapjack octopus
# 2329                NaN               NaN         southern sand octopus
# 2389                NaN               NaN                           NaN
# 2610                NaN               NaN   california two-spot octopus
# 2663                NaN               NaN    gelatinous blanket octopus
# 2739                NaN               NaN                           NaN
# 2750                NaN               NaN                           NaN
# 2767                NaN               NaN             Tehuelche octopus
# 2768                NaN               NaN                           NaN
# 2809                NaN               NaN                           NaN
# 2886                NaN               NaN      East Pacific red octopus
# 2957                NaN               NaN                           NaN
# 3133                NaN               NaN                           NaN
# 3163                NaN  paper nautiluses         rough-keeled argonaut
# 3222                NaN               NaN                           NaN
# 3438                NaN               NaN                           NaN
# 3589                NaN               NaN                           NaN
# 3685                NaN               NaN                           NaN
# 3729                NaN               NaN                   map octopus

# %%
df_common_names['common_name'] = df_common_names['common_name_family']
df_common_names.loc[df_common_names['common_name'].isna(), 'common_name'] = df_common_names.loc[df_common_names['common_name'].isna()]['common_name_order']

# %%
len(df_common_names), df_common_names['common_name'].isna().sum()
# Out:
# (3797, 156)

# %%
df_common_names.loc[df_common_names['common_name'].isna(), 'common_name'] = df_common_names.loc[df_common_names['common_name'].isna()]['common_name_genus']
len(df_common_names), df_common_names['common_name'].isna().sum()
# Out:
# (3797, 140)

# %%
df_common_names.loc[df_common_names['common_name'].isna(), 'common_name'] = df_common_names.loc[df_common_names['common_name'].isna()]['common_name_species']
len(df_common_names), df_common_names['common_name'].isna().sum()
# Out:
# (3797, 0)

# %%
df_common_names['common_name'].value_counts()
# Out:
# groupers             146
# rainbowfishes        128
# damselfishes         115
# stony coral          114
# sea slug              99
#                     ...
# heart urchins          1
# edible sea urchin      1
# branching sponge       1
# pineconefishes         1
# land hermit crabs      1
# Name: common_name, Length: 571, dtype: int64

# %%
df_common_names.dropna(subset=['common_name_order'])[df_common_names.dropna(subset=['common_name_order'])['common_name_order'].str.contains('coral')]
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 36         714       3950   7876869     9783587       stony coral
# 138        714    7526997   2260569     2260570       stony coral
# 221       1437       3933   2238567     5185175       soft corals
# 261       1242       8181   2256373     2260700    coral anemones
# 305       1437       3958   4878948     9809158       soft corals
# ...        ...        ...       ...         ...               ...
# 3807       831         -1        -1          -1       black coral
# 3829      1437       3933        -1          -1       soft corals
# 3874      1437       8198   2258179          -1       soft corals
# 3906      1437       7313   1002810          -1       soft corals
# 3911       714       3950   2259152     2259158       stony coral
#
#      common_name_family  common_name_genus   common_name_species  \
# 36           cup corals                NaN                   NaN
# 138                 NaN                NaN         octopus coral
# 221          alcyoniids                NaN    dead man's fingers
# 261                 NaN                NaN         jewel anemone
# 305                 NaN                NaN                   NaN
# ...                 ...                ...                   ...
# 3807                NaN                NaN                   NaN
# 3829         alcyoniids                NaN                   NaN
# 3874                NaN           sea fans                   NaN
# 3906                NaN  organ-pipe corals                   NaN
# 3911         cup corals          Cup Coral  Devonshire cup coral
#
#          common_name
# 36        cup corals
# 138      stony coral
# 221       alcyoniids
# 261   coral anemones
# 305      soft corals
# ...              ...
# 3807     black coral
# 3829      alcyoniids
# 3874     soft corals
# 3906     soft corals
# 3911      cup corals
#
# [180 rows x 9 columns]

# %%
df_common_names.dropna(subset=['common_name_order'])[df_common_names.dropna(subset=['common_name_order'])['common_name_order'].str.contains('anemon')]
# Out:
#       orderKey  familyKey  genusKey  speciesKey common_name_order  \
# 122        705       9220   2256991     2257005       sea anemone
# 246        705       5688   2256131     2256644       sea anemone
# 261       1242       8181   2256373     2260700    coral anemones
# 407        705       5688   2256131     2256631       sea anemone
# 775        705       9220   2256762     5184183       sea anemone
# 789        705       5141   2257814     2257817       sea anemone
# 950        705       5141   2257814     2257843       sea anemone
# 1076       705       5688   8424301     2256559       sea anemone
# 1097       705       5141   2255718     2257884       sea anemone
# 1138       705       9214   2255724     5183974       sea anemone
# 1169       705       9220   2256991     7812410       sea anemone
# 1220       705       5688   2256124     2256780       sea anemone
# 1413       705       5141   2255718     2257892       sea anemone
# 1426       705       9220   2256762     5184187       sea anemone
# 1520       705       5688   2256125     5711876       sea anemone
# 1582       705       9203   2256249     2256258       sea anemone
# 1678       705       9214   2255724     9789416       sea anemone
# 1875       705       5688   2256802     2256805       sea anemone
# 2025       705       9208   2257113     2257114       sea anemone
# 2027       705       5688   2256740     2256741       sea anemone
# 2104       705       9204   2255866     2257274       sea anemone
# 2239       705       5134   2257365    10570072       sea anemone
# 2307       705    4339241   2255786     2255846       sea anemone
# 2466       705       5688   2256681     2256682       sea anemone
# 2510       705       5134   2257299     5184247       sea anemone
# 2553      1242    4283414   2257197     6472327    coral anemones
# 2619       705       5688   2255932     2256950       sea anemone
# 2620       705       5688   2256813     2256825       sea anemone
# 2645       705       5134   2257568     2257570       sea anemone
# 2646       705       5129   2255865     2257924       sea anemone
# 2776       705       5141   8192236     5184341       sea anemone
# 2777       705       5134   2257365     2257373       sea anemone
# 2803       705       5688   2256802     2256804       sea anemone
# 2939       705       9220   2256991     2256992       sea anemone
# 3090       705       9220   2256762     5184174       sea anemone
# 3146       705       5141   2257814     2257815       sea anemone
# 3147       705       5131   2255928     2255989       sea anemone
# 3279       705         -1        -1          -1       sea anemone
# 3314       705       5129   2255865     2257920       sea anemone
# 3359       705       9204   2257297     4339299       sea anemone
# 3361       705       5688   2256813     2256852       sea anemone
# 3501       705       9214   2255724          -1       sea anemone
# 3526       705       5142   2257666     2257667       sea anemone
# 3848       705       5688   2256813     4339104       sea anemone
# 3850       705       5688   8424301     2256565       sea anemone
#
#      common_name_family common_name_genus                common_name_species  \
# 122                 NaN               NaN                      giant anemone
# 246                 NaN               NaN                 snakelocks anemone
# 261                 NaN               NaN                      jewel anemone
# 407                 NaN               NaN                                NaN
# 775                 NaN               NaN            magnificent sea anemone
# 789                 NaN               NaN                   fountain anemone
# 950                 NaN               NaN           small snakelocks anemone
# 1076                NaN       Sea anemone                    beadlet anemone
# 1097                NaN               NaN                       mud sagartia
# 1138                NaN               NaN             clonal plumose anemone
# 1169                NaN               NaN               Haddon's sea anemone
# 1220                NaN               NaN                     dahlia anemone
# 1413                NaN               NaN                    elegant anemone
# 1426                NaN               NaN                 beaded sea anemone
# 1520                NaN               NaN                deeplet sea anemone
# 1582                NaN               NaN                   swimming anemone
# 1678                NaN               NaN                                NaN
# 1875                NaN               NaN                        fat anemone
# 2025                NaN               NaN                    sealoch anemone
# 2027                NaN               NaN            giant Caribbean anenone
# 2104                NaN               NaN                    trumpet anemone
# 2239                NaN               NaN                                NaN
# 2307                NaN               NaN                                NaN
# 2466                NaN               NaN                                NaN
# 2510                NaN               NaN                      cloak anemone
# 2553                NaN               NaN                                NaN
# 2619                NaN               NaN                      sandy anemone
# 2620                NaN               NaN                        sun anemone
# 2645                NaN               NaN                          seanemone
# 2646                NaN               NaN                     orange anemone
# 2776                NaN               NaN                      daisy anemone
# 2777                NaN               NaN                  parasitic anemone
# 2803                NaN               NaN           fernald brooding anemone
# 2939                NaN               NaN               Merten's sea anemone
# 3090                NaN               NaN               leathery sea anemone
# 3146                NaN               NaN                                NaN
# 3147                NaN               NaN  twelve-tentacle burrowing anemone
# 3279                NaN               NaN                                NaN
# 3314                NaN               NaN                      white anemone
# 3359                NaN               NaN                                NaN
# 3361                NaN               NaN                giant green anemone
# 3501                NaN               NaN                                NaN
# 3526                NaN               NaN               adhesive sea anemone
# 3848                NaN               NaN                                NaN
# 3850                NaN       Sea anemone                 strawberry anemone
#
#          common_name
# 122      sea anemone
# 246      sea anemone
# 261   coral anemones
# 407      sea anemone
# 775      sea anemone
# 789      sea anemone
# 950      sea anemone
# 1076     sea anemone
# 1097     sea anemone
# 1138     sea anemone
# 1169     sea anemone
# 1220     sea anemone
# 1413     sea anemone
# 1426     sea anemone
# 1520     sea anemone
# 1582     sea anemone
# 1678     sea anemone
# 1875     sea anemone
# 2025     sea anemone
# 2027     sea anemone
# 2104     sea anemone
# 2239     sea anemone
# 2307     sea anemone
# 2466     sea anemone
# 2510     sea anemone
# 2553  coral anemones
# 2619     sea anemone
# 2620     sea anemone
# 2645     sea anemone
# 2646     sea anemone
# 2776     sea anemone
# 2777     sea anemone
# 2803     sea anemone
# 2939     sea anemone
# 3090     sea anemone
# 3146     sea anemone
# 3147     sea anemone
# 3279     sea anemone
# 3314     sea anemone
# 3359     sea anemone
# 3361     sea anemone
# 3501     sea anemone
# 3526     sea anemone
# 3848     sea anemone
# 3850     sea anemone

# %%
#Assign common name to each observation
df = df.merge(df_common_names, how='left', on=['orderKey','familyKey','genusKey','speciesKey'])

# %%
df['common_name'].isna().sum()
# Out:
# 257

# %%
#Target
max_species = df['common_name'].str.strip().value_counts().index[0]
df['target'] = (df['common_name'] == max_species).astype(int)

# %%
df['target'].sum()
# Out:
# 2001

# %%
#Aggregate rows by inmersion
#If the most popular species is seen during the dive, then target is equal to 1
df_count_target = df.groupby('dive_id')['target'].sum().reset_index()
df_count_target.loc[df_count_target['target'] >= 1, 'target'] = 1

df = df.drop(columns='target')
df_unique = df.drop_duplicates(subset='dive_id')

df = df_unique.merge(df_count_target, how='left', on='dive_id')
df
# Out:
#                  eventDate  month  day            waterBody countryCode  \
# 0      2019-05-29T10:06:00      5   29  South Pacific Ocean          WS
# 1      2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 2      2019-05-30T12:04:00      5   30  South Pacific Ocean          WS
# 3      2019-05-30T10:02:00      5   30  South Pacific Ocean          WS
# 4      2015-07-22T18:56:00      7   22          Hidden Lake          EG
# ...                    ...    ...  ...                  ...         ...
# 11568  2015-02-24T09:06:00      2   24  South Pacific Ocean          FJ
# 11569  2015-02-26T11:22:00      2   26  South Pacific Ocean          FJ
# 11570  2015-02-25T08:54:00      2   25  South Pacific Ocean          FJ
# 11571  2015-02-25T10:51:00      2   25  South Pacific Ocean          FJ
# 11572  1992-12-06T09:00:00     12    6  South Pacific Ocean          FJ
#
#                                                locality  \
# 0                                                Taliga
# 1                                             Cowabunga
# 2                                             Cowabunga
# 3                                             Cowabunga
# 4      Sunrise Grand Select Montemare Resort House Reef
# ...                                                 ...
# 11568                                    Barracuda Hole
# 11569                                    Annie's Bommie
# 11570                                     Yellow Tunnel
# 11571                                   Rainbow Passage
# 11572                                          Sand Cay
#
#                       species  dive_id  decimalLatitude  decimalLongitude  \
# 0              Chelonia mydas     2422         -13.9387          -171.553
# 1      Eretmochelys imbricata     2423         -13.9387          -171.553
# 2              Chelonia mydas     2425         -13.9387          -171.553
# 3      Eretmochelys imbricata     2424         -13.9387          -171.553
# 4            Scarus psittacus     7258          53.8635          -166.049
# ...                       ...      ...              ...               ...
# 11568       Triaenodon obesus     1125         -16.7868           179.918
# 11569      Heteroconger hassi     1123         -16.7861           179.924
# 11570          Naso lituratus     1126         -16.7861           179.924
# 11571          Mobula alfredi     1124         -16.7861           179.924
# 11572        Diodon liturosus     6861         -16.9000           179.983
#
#         depth   orderKey  familyKey   genusKey  speciesKey common_name_order  \
# 0      13.500      793.0     9413.0  2441864.0   2442225.0            turtle
# 1      10.200      793.0     9413.0  2442206.0   8841716.0            turtle
# 2       9.750      793.0     9413.0  2441864.0   2442225.0            turtle
# 3      10.500      793.0     9413.0  2442206.0   8841716.0            turtle
# 4      10.000      587.0     4504.0  2371535.0   2393800.0   perch-like fish
# ...       ...        ...        ...        ...         ...               ...
# 11568  13.870      887.0     2211.0  2418205.0   2418054.0      ground shark
# 11569  12.210      495.0     2951.0  2403127.0   2403157.0               eel
# 11570  12.790      587.0     4233.0  2379541.0   5209096.0   perch-like fish
# 11571  12.955  8214029.0     2193.0  2419178.0   9241141.0          stingray
# 11572   9.000      772.0     5898.0  2406531.0   5213358.0         cowfishes
#
#       common_name_family      common_name_genus           common_name_species  \
# 0            Sea Turtles       green sea turtle                  Green turtle
# 1            Sea Turtles  Hawksbill Sea Turtles              Hawksbill turtle
# 2            Sea Turtles       green sea turtle                  Green turtle
# 3            Sea Turtles  Hawksbill Sea Turtles              Hawksbill turtle
# 4           parrotfishes           parrotfishes           Palenose parrotfish
# ...                  ...                    ...                           ...
# 11568      requiem shark                    NaN           whitetip reef shark
# 11569         conger eel             garden eel      Black spotted garden eel
# 11570      surgeonfishes             nosefishes      striped-face unicornfish
# 11571          eagle ray              devil ray                  Alfred manta
# 11572         burrfishes        porcupinefishes  Black blotched porcupinefish
#
#          common_name  target
# 0        Sea Turtles       0
# 1        Sea Turtles       0
# 2        Sea Turtles       0
# 3        Sea Turtles       0
# 4       parrotfishes       0
# ...              ...     ...
# 11568  requiem shark       0
# 11569     conger eel       0
# 11570  surgeonfishes       0
# 11571      eagle ray       0
# 11572     burrfishes       0
#
# [11573 rows x 21 columns]

# %%
#Extract hours from eventDate column
df['hour'] = df['eventDate'].str.split('T')[:].str[1].str.split(':').str[0].astype('int')
df.head()
# Out:
#              eventDate  month  day            waterBody countryCode  \
# 0  2019-05-29T10:06:00      5   29  South Pacific Ocean          WS
# 1  2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 2  2019-05-30T12:04:00      5   30  South Pacific Ocean          WS
# 3  2019-05-30T10:02:00      5   30  South Pacific Ocean          WS
# 4  2015-07-22T18:56:00      7   22          Hidden Lake          EG
#
#                                            locality                 species  \
# 0                                            Taliga          Chelonia mydas
# 1                                         Cowabunga  Eretmochelys imbricata
# 2                                         Cowabunga          Chelonia mydas
# 3                                         Cowabunga  Eretmochelys imbricata
# 4  Sunrise Grand Select Montemare Resort House Reef        Scarus psittacus
#
#    dive_id  decimalLatitude  decimalLongitude  depth  orderKey  familyKey  \
# 0     2422         -13.9387          -171.553  13.50     793.0     9413.0
# 1     2423         -13.9387          -171.553  10.20     793.0     9413.0
# 2     2425         -13.9387          -171.553   9.75     793.0     9413.0
# 3     2424         -13.9387          -171.553  10.50     793.0     9413.0
# 4     7258          53.8635          -166.049  10.00     587.0     4504.0
#
#     genusKey  speciesKey common_name_order common_name_family  \
# 0  2441864.0   2442225.0            turtle        Sea Turtles
# 1  2442206.0   8841716.0            turtle        Sea Turtles
# 2  2441864.0   2442225.0            turtle        Sea Turtles
# 3  2442206.0   8841716.0            turtle        Sea Turtles
# 4  2371535.0   2393800.0   perch-like fish       parrotfishes
#
#        common_name_genus  common_name_species   common_name  target  hour
# 0       green sea turtle         Green turtle   Sea Turtles       0    10
# 1  Hawksbill Sea Turtles     Hawksbill turtle   Sea Turtles       0    12
# 2       green sea turtle         Green turtle   Sea Turtles       0    12
# 3  Hawksbill Sea Turtles     Hawksbill turtle   Sea Turtles       0    10
# 4           parrotfishes  Palenose parrotfish  parrotfishes       0    18

# %%
#Convert hour, day and month to sine and cosine
def to_sin(df, column):
    df[column+'_sin'] = df.apply(lambda row: np.sin(2*np.pi*row[column]/24), axis=1)
    
def to_cos(df, column):
    df[column+'_cos'] = df.apply(lambda row: np.cos(2*np.pi*row[column]/24), axis=1)

# %%
to_sin(df, 'hour')
to_cos(df, 'hour')
to_sin(df, 'day')
to_cos(df, 'day')
to_sin(df, 'month')
to_cos(df, 'month')

# %%
df
# Out:
#                  eventDate  month  day            waterBody countryCode  \
# 0      2019-05-29T10:06:00      5   29  South Pacific Ocean          WS
# 1      2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 2      2019-05-30T12:04:00      5   30  South Pacific Ocean          WS
# 3      2019-05-30T10:02:00      5   30  South Pacific Ocean          WS
# 4      2015-07-22T18:56:00      7   22          Hidden Lake          EG
# ...                    ...    ...  ...                  ...         ...
# 11568  2015-02-24T09:06:00      2   24  South Pacific Ocean          FJ
# 11569  2015-02-26T11:22:00      2   26  South Pacific Ocean          FJ
# 11570  2015-02-25T08:54:00      2   25  South Pacific Ocean          FJ
# 11571  2015-02-25T10:51:00      2   25  South Pacific Ocean          FJ
# 11572  1992-12-06T09:00:00     12    6  South Pacific Ocean          FJ
#
#                                                locality  \
# 0                                                Taliga
# 1                                             Cowabunga
# 2                                             Cowabunga
# 3                                             Cowabunga
# 4      Sunrise Grand Select Montemare Resort House Reef
# ...                                                 ...
# 11568                                    Barracuda Hole
# 11569                                    Annie's Bommie
# 11570                                     Yellow Tunnel
# 11571                                   Rainbow Passage
# 11572                                          Sand Cay
#
#                       species  dive_id  decimalLatitude  decimalLongitude  \
# 0              Chelonia mydas     2422         -13.9387          -171.553
# 1      Eretmochelys imbricata     2423         -13.9387          -171.553
# 2              Chelonia mydas     2425         -13.9387          -171.553
# 3      Eretmochelys imbricata     2424         -13.9387          -171.553
# 4            Scarus psittacus     7258          53.8635          -166.049
# ...                       ...      ...              ...               ...
# 11568       Triaenodon obesus     1125         -16.7868           179.918
# 11569      Heteroconger hassi     1123         -16.7861           179.924
# 11570          Naso lituratus     1126         -16.7861           179.924
# 11571          Mobula alfredi     1124         -16.7861           179.924
# 11572        Diodon liturosus     6861         -16.9000           179.983
#
#         depth   orderKey  familyKey   genusKey  speciesKey common_name_order  \
# 0      13.500      793.0     9413.0  2441864.0   2442225.0            turtle
# 1      10.200      793.0     9413.0  2442206.0   8841716.0            turtle
# 2       9.750      793.0     9413.0  2441864.0   2442225.0            turtle
# 3      10.500      793.0     9413.0  2442206.0   8841716.0            turtle
# 4      10.000      587.0     4504.0  2371535.0   2393800.0   perch-like fish
# ...       ...        ...        ...        ...         ...               ...
# 11568  13.870      887.0     2211.0  2418205.0   2418054.0      ground shark
# 11569  12.210      495.0     2951.0  2403127.0   2403157.0               eel
# 11570  12.790      587.0     4233.0  2379541.0   5209096.0   perch-like fish
# 11571  12.955  8214029.0     2193.0  2419178.0   9241141.0          stingray
# 11572   9.000      772.0     5898.0  2406531.0   5213358.0         cowfishes
#
#       common_name_family      common_name_genus           common_name_species  \
# 0            Sea Turtles       green sea turtle                  Green turtle
# 1            Sea Turtles  Hawksbill Sea Turtles              Hawksbill turtle
# 2            Sea Turtles       green sea turtle                  Green turtle
# 3            Sea Turtles  Hawksbill Sea Turtles              Hawksbill turtle
# 4           parrotfishes           parrotfishes           Palenose parrotfish
# ...                  ...                    ...                           ...
# 11568      requiem shark                    NaN           whitetip reef shark
# 11569         conger eel             garden eel      Black spotted garden eel
# 11570      surgeonfishes             nosefishes      striped-face unicornfish
# 11571          eagle ray              devil ray                  Alfred manta
# 11572         burrfishes        porcupinefishes  Black blotched porcupinefish
#
#          common_name  target  hour      hour_sin      hour_cos       day_sin  \
# 0        Sea Turtles       0    10  5.000000e-01 -8.660254e-01  9.659258e-01
# 1        Sea Turtles       0    12  1.224647e-16 -1.000000e+00  9.659258e-01
# 2        Sea Turtles       0    12  1.224647e-16 -1.000000e+00  1.000000e+00
# 3        Sea Turtles       0    10  5.000000e-01 -8.660254e-01  1.000000e+00
# 4       parrotfishes       0    18 -1.000000e+00 -1.836970e-16 -5.000000e-01
# ...              ...     ...   ...           ...           ...           ...
# 11568  requiem shark       0     9  7.071068e-01 -7.071068e-01 -2.449294e-16
# 11569     conger eel       0    11  2.588190e-01 -9.659258e-01  5.000000e-01
# 11570  surgeonfishes       0     8  8.660254e-01 -5.000000e-01  2.588190e-01
# 11571      eagle ray       0    10  5.000000e-01 -8.660254e-01  2.588190e-01
# 11572     burrfishes       0     9  7.071068e-01 -7.071068e-01  1.000000e+00
#
#             day_cos     month_sin  month_cos
# 0      2.588190e-01  9.659258e-01   0.258819
# 1      2.588190e-01  9.659258e-01   0.258819
# 2      1.194340e-15  9.659258e-01   0.258819
# 3      1.194340e-15  9.659258e-01   0.258819
# 4      8.660254e-01  9.659258e-01  -0.258819
# ...             ...           ...        ...
# 11568  1.000000e+00  5.000000e-01   0.866025
# 11569  8.660254e-01  5.000000e-01   0.866025
# 11570  9.659258e-01  5.000000e-01   0.866025
# 11571  9.659258e-01  5.000000e-01   0.866025
# 11572  6.123234e-17  1.224647e-16  -1.000000
#
# [11573 rows x 28 columns]

# %% [markdown]
# #Obtain day of week
# df['weekday'] = pd.to_datetime(df['eventDate']).dt.weekday
# df.head()

# %%
#Mean target encoder for categorical columns
def mean_target_encoder(df, column, target):
    m_dict = dict(df.groupby(column).mean()[target])
    df[column+'_m'] = df[column].map(m_dict)

# %%
mean_target_encoder(df, 'waterBody', 'target')
mean_target_encoder(df, 'locality', 'target')
mean_target_encoder(df, 'countryCode', 'target')

# %%
df.head()
# Out:
#              eventDate  month  day            waterBody countryCode  \
# 0  2019-05-29T10:06:00      5   29  South Pacific Ocean          WS
# 1  2019-05-29T12:15:00      5   29  South Pacific Ocean          WS
# 2  2019-05-30T12:04:00      5   30  South Pacific Ocean          WS
# 3  2019-05-30T10:02:00      5   30  South Pacific Ocean          WS
# 4  2015-07-22T18:56:00      7   22          Hidden Lake          EG
#
#                                            locality                 species  \
# 0                                            Taliga          Chelonia mydas
# 1                                         Cowabunga  Eretmochelys imbricata
# 2                                         Cowabunga          Chelonia mydas
# 3                                         Cowabunga  Eretmochelys imbricata
# 4  Sunrise Grand Select Montemare Resort House Reef        Scarus psittacus
#
#    dive_id  decimalLatitude  decimalLongitude  depth  orderKey  familyKey  \
# 0     2422         -13.9387          -171.553  13.50     793.0     9413.0
# 1     2423         -13.9387          -171.553  10.20     793.0     9413.0
# 2     2425         -13.9387          -171.553   9.75     793.0     9413.0
# 3     2424         -13.9387          -171.553  10.50     793.0     9413.0
# 4     7258          53.8635          -166.049  10.00     587.0     4504.0
#
#     genusKey  speciesKey common_name_order common_name_family  \
# 0  2441864.0   2442225.0            turtle        Sea Turtles
# 1  2442206.0   8841716.0            turtle        Sea Turtles
# 2  2441864.0   2442225.0            turtle        Sea Turtles
# 3  2442206.0   8841716.0            turtle        Sea Turtles
# 4  2371535.0   2393800.0   perch-like fish       parrotfishes
#
#        common_name_genus  common_name_species   common_name  target  hour  \
# 0       green sea turtle         Green turtle   Sea Turtles       0    10
# 1  Hawksbill Sea Turtles     Hawksbill turtle   Sea Turtles       0    12
# 2       green sea turtle         Green turtle   Sea Turtles       0    12
# 3  Hawksbill Sea Turtles     Hawksbill turtle   Sea Turtles       0    10
# 4           parrotfishes  Palenose parrotfish  parrotfishes       0    18
#
#        hour_sin      hour_cos   day_sin       day_cos  month_sin  month_cos  \
# 0  5.000000e-01 -8.660254e-01  0.965926  2.588190e-01   0.965926   0.258819
# 1  1.224647e-16 -1.000000e+00  0.965926  2.588190e-01   0.965926   0.258819
# 2  1.224647e-16 -1.000000e+00  1.000000  1.194340e-15   0.965926   0.258819
# 3  5.000000e-01 -8.660254e-01  1.000000  1.194340e-15   0.965926   0.258819
# 4 -1.000000e+00 -1.836970e-16 -0.500000  8.660254e-01   0.965926  -0.258819
#
#    waterBody_m  locality_m  countryCode_m
# 0     0.145299         0.0       0.000000
# 1     0.145299         0.0       0.000000
# 2     0.145299         0.0       0.000000
# 3     0.145299         0.0       0.000000
# 4     0.000000         0.0       0.213318

# %%
#Standardize
sc = StandardScaler()
df['depth_s'] = sc.fit_transform(df[['depth']])

# %%
#Split data in X and y
X = df.drop(columns='target')
y = df['target']

# %%
X.columns
# Out:
# Index(['eventDate', 'month', 'day', 'waterBody', 'countryCode', 'locality',
#        'species', 'dive_id', 'decimalLatitude', 'decimalLongitude', 'depth',
#        'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'common_name_order',
#        'common_name_family', 'common_name_genus', 'common_name_species',
#        'common_name', 'hour', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos',
#        'month_sin', 'month_cos', 'waterBody_m', 'locality_m', 'countryCode_m',
#        'depth_s'],
#       dtype='object')

# %%
categorical_columns = ['waterBody_m', 'locality_m', 'countryCode_m']
numerical_columns = ['hour_sin', 'hour_cos', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'depth']

# %%
# Chi2
fs = SelectKBest(score_func=chi2, k='all')
fs.fit(X[categorical_columns], y)
X_fs = fs.transform(X[categorical_columns])

# %%
for i,col in enumerate(categorical_columns):
    print('Feature %s score: %f p_valor: %s' % (col, fs.scores_[i], fs.pvalues_[i]))

plt.figure(figsize=(10,8))
plt.bar(categorical_columns, fs.scores_)
plt.show()
# Out:
# Feature waterBody_m score: 123.548420 p_valor: 1.0577336022750726e-28
# Feature locality_m score: 3194.813024 p_valor: 0.0
# Feature countryCode_m score: 38.738687 p_valor: 4.845102301078471e-10

# %%
# Mutual information
fs = SelectKBest(score_func=mutual_info_classif, k='all')
fs.fit(X[categorical_columns], y)
X_fs = fs.transform(X[categorical_columns])

# %%
# The highest, the more dependency
for i,col in enumerate(categorical_columns):
    print('Feature %s %f' % (col, fs.scores_[i]))

plt.figure(figsize=(10,8))
plt.bar(categorical_columns, fs.scores_)
plt.show()
# Out:
# Feature waterBody_m 0.061683
# Feature locality_m 0.262686
# Feature countryCode_m 0.033689

# %%
#Anova
fs = SelectKBest(score_func=f_classif, k='all')
fs.fit(X[numerical_columns], y)
X_fs = fs.transform(X[numerical_columns])

# %%
for i,col in enumerate(numerical_columns):
    print('Feature %s score: %f p_valor: %s' % (col, fs.scores_[i], fs.pvalues_[i]))

plt.figure(figsize=(10,8))
plt.bar(numerical_columns, fs.scores_)
plt.show()
# Out:
# Feature hour_sin score: 3.827688 p_valor: 0.050436452244447004
# Feature hour_cos score: 0.350189 p_valor: 0.554017464833147
# Feature day_sin score: 0.017574 p_valor: 0.8945393650319613
# Feature day_cos score: 9.534899 p_valor: 0.002020783374867911
# Feature month_sin score: 17.317262 p_valor: 3.185880290216238e-05
# Feature month_cos score: 1.392312 p_valor: 0.23803927703124775
# Feature depth score: 66.808370 p_valor: 3.303389947248444e-16

# %%
#Export dataframe
columns = ['decimalLatitude', 'decimalLongitude', 'waterBody', 'locality', 'countryCode', 'hour_sin',
           'hour_cos', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'depth', 'target']
df = df[columns]
df.to_csv('./data/occurrence_selected.txt', index=False)
